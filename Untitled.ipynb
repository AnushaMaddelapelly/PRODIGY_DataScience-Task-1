# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('Task 1.csv')
df.head()
# Out:
#       Indicator Name Indicator Code                 Country Name Country Code  \
# 0  Population, total    SP.POP.TOTL                        Aruba          ABW
# 1  Population, total    SP.POP.TOTL  Africa Eastern and Southern          AFE
# 2  Population, total    SP.POP.TOTL                  Afghanistan          AFG
# 3  Population, total    SP.POP.TOTL   Africa Western and Central          AFW
# 4  Population, total    SP.POP.TOTL                       Angola          AGO
#
#           2000         2001         2002         2003         2004  \
# 0      89101.0      90691.0      91781.0      92701.0      93540.0
# 1  401600588.0  412001885.0  422741118.0  433807484.0  445281555.0
# 2   19542982.0   19688632.0   21000256.0   22645130.0   23553551.0
# 3  269611898.0  277160097.0  284952322.0  292977949.0  301265247.0
# 4   16394062.0   16941587.0   17516139.0   18124342.0   18771125.0
#
#           2005  ...         2014         2015         2016         2017  \
# ...

# %%
df=pd.read_csv('Task 1.csv',index_col=0)
df.index=df.index.str.strip()
if 'Population, female' in df.index:
    female_population=df.loc["Population, female"]
    print("Population, female Data:\n",female_population)
else:
    print("Error: 'Population, female' not found in the index.")
    print("Available indices:",df.index.tolist())
# Out:
# Population, female Data:
#                         Indicator Code                 Country Name  \
# Indicator Name
# Population, female  SP.POP.TOTL.FE.IN                        Aruba
# Population, female  SP.POP.TOTL.FE.IN  Africa Eastern and Southern
# Population, female  SP.POP.TOTL.FE.IN                  Afghanistan
# Population, female  SP.POP.TOTL.FE.IN   Africa Western and Central
# Population, female  SP.POP.TOTL.FE.IN                       Angola
# ...                               ...                          ...
# Population, female  SP.POP.TOTL.FE.IN                       Kosovo
# Population, female  SP.POP.TOTL.FE.IN                  Yemen, Rep.
# Population, female  SP.POP.TOTL.FE.IN                 South Africa
# Population, female  SP.POP.TOTL.FE.IN                       Zambia
# Population, female  SP.POP.TOTL.FE.IN                     Zimbabwe
#
#                    Country Code         2000         2001         2002  \
# Indicator Name
# ...

# %%
data={
    'year':[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],
    'Female Population':[599047591,607376801,615647779,623809180,631697152,639323292,647012921,654607791,661854076,668786993,675389679,681060412,685992675,691776131]
}
df=pd.DataFrame(data)
plt.bar(df['year'], df['Female Population'])
plt.xlabel('year')
plt.ylabel('population female')
plt.title('Female Population in India from 2010-2023')
plt.show()

# %%
data={
    'country_names':['canada','Bahrain','Australia','India'],
    'total_population':[373790876,13150775,250360863,1453404513]
}
df=pd.DataFrame(data)
plt.figure(figsize=(8,6))
plt.bar(df['country_names'],df['total_population'],color='red')
plt.xlabel('country')
plt.ylabel('Total Population')
plt.title('Population total from 2014 to 2023')
plt.show()

# %%
plotdata=pd.DataFrame({
    'country names':['Maldives','Aruba','Iceland','Malta','Sri Lanka'],
    'total population':[521021,106277,393600,553214,22037000],
    'female population':[222431,56225,191856,264733,11428453],
    'male population':[298591,50052,201745,288481,10608547]
})
df=pd.DataFrame(plotdata)
plotdata.plot(x='country names',y=['total population','female population','male population'],kind='bar',figsize=(15,8))
plt.title('Population Distribution by country in 2023')
plt.show()
